# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | te anau
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 1 | tongliao
# Processing Record 6 of Set 1 | oropesa
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | moron
# Processing Record 9 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | ginda
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | alta floresta
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | mayo
# Processing Record 18 of Set 1 | jinxiang
# Processing Record 19 of Set 1 | nevelsk
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | tolaga bay
# Processing Record 22 of Set 1 | port blair
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | nioki
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | ballina
# Processing Record 31 of Set 1 | coquimbo
# Processing Record 32 of Set 1 | norsup
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | la ronge
# Processing Record 41 of Set 1 | znin
# Processing Record 42 of Set 1 | nishihara
# Processing Record 43 of Set 1 | berezovyy
# Processing Record 44 of Set 1 | dutse
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | los llanos de aridane
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | skjervoy
# Processing Record 49 of Set 1 | fomboni
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | inhambane
# Processing Record 2 of Set 2 | pisco
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | sweetwater
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | shahada
# Processing Record 10 of Set 2 | salinopolis
# Processing Record 11 of Set 2 | karia
# Processing Record 12 of Set 2 | saiha
# Processing Record 13 of Set 2 | santa vitoria do palmar
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | kuching
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | shenjiamen
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | khanpur
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | yangambi
# Processing Record 25 of Set 2 | olafsvik
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | motygino
# Processing Record 29 of Set 2 | awbari
# Processing Record 30 of Set 2 | kysyl-syr
# Processing Record 31 of Set 2 | davidson
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | soe
# Processing Record 35 of Set 2 | acarau
# Processing Record 36 of Set 2 | malyye derbety
# Processing Record 37 of Set 2 | turukhansk
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | muisne
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | deputatskiy
# Processing Record 42 of Set 2 | jeremie
# Processing Record 43 of Set 2 | lagoa
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | fuxin
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | alice springs
# Processing Record 49 of Set 2 | baishishan
# Processing Record 50 of Set 2 | ziro
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | plerin
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | vaini
# Processing Record 5 of Set 3 | marawi
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | faridan
# City not found. Skipping...
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | suvorovo
# Processing Record 11 of Set 3 | qaqortoq
# Processing Record 12 of Set 3 | mataura
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | kapit
# Processing Record 17 of Set 3 | talas
# Processing Record 18 of Set 3 | muzhi
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | palembang
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | kurumkan
# Processing Record 25 of Set 3 | parkersburg
# Processing Record 26 of Set 3 | harper
# Processing Record 27 of Set 3 | solnechnyy
# Processing Record 28 of Set 3 | tahta
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | makakilo city
# Processing Record 33 of Set 3 | sitka
# Processing Record 34 of Set 3 | atuona
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | les cayes
# Processing Record 37 of Set 3 | merauke
# Processing Record 38 of Set 3 | zhumadian
# Processing Record 39 of Set 3 | seoul
# Processing Record 40 of Set 3 | saint-joseph
# Processing Record 41 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 3 | pergamino
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | bone
# Processing Record 45 of Set 3 | uige
# Processing Record 46 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | kununurra
# Processing Record 50 of Set 3 | peniche
# Processing Record 1 of Set 4 | sungaipenuh
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | savannah bight
# Processing Record 4 of Set 4 | thilogne
# City not found. Skipping...
# Processing Record 5 of Set 4 | newport
# Processing Record 6 of Set 4 | labuhan
# Processing Record 7 of Set 4 | akhtanizovskaya
# Processing Record 8 of Set 4 | gillette
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | kasaragod
# Processing Record 12 of Set 4 | dalvik
# Processing Record 13 of Set 4 | ambanja
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | butaritari
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | koster
# Processing Record 20 of Set 4 | severnoye
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | jalu
# Processing Record 25 of Set 4 | amapa
# Processing Record 26 of Set 4 | bujaru
# Processing Record 27 of Set 4 | fairbanks
# Processing Record 28 of Set 4 | qui nhon
# Processing Record 29 of Set 4 | vestmanna
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | nixa
# Processing Record 32 of Set 4 | kijang
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | ostersund
# Processing Record 35 of Set 4 | vanavara
# Processing Record 36 of Set 4 | boa vista
# Processing Record 37 of Set 4 | jacobina
# Processing Record 38 of Set 4 | bowen
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | carballo
# Processing Record 41 of Set 4 | cayenne
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | beringovskiy
# Processing Record 44 of Set 4 | college
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | ho
# City not found. Skipping...
# Processing Record 47 of Set 4 | woodward
# Processing Record 48 of Set 4 | nyurba
# Processing Record 49 of Set 4 | broome
# Processing Record 50 of Set 4 | bredasdorp
# Processing Record 1 of Set 5 | vila
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | landeck
# Processing Record 4 of Set 5 | damietta
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | necochea
# Processing Record 9 of Set 5 | belmopan
# Processing Record 10 of Set 5 | basyanovskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | beira
# Processing Record 12 of Set 5 | sterling
# Processing Record 13 of Set 5 | casablanca
# Processing Record 14 of Set 5 | udachnyy
# Processing Record 15 of Set 5 | havoysund
# Processing Record 16 of Set 5 | camana
# Processing Record 17 of Set 5 | airai
# Processing Record 18 of Set 5 | vanimo
# Processing Record 19 of Set 5 | pemangkat
# Processing Record 20 of Set 5 | kommunar
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | buala
# Processing Record 23 of Set 5 | kalmar
# Processing Record 24 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 5 | nalut
# Processing Record 26 of Set 5 | forio
# Processing Record 27 of Set 5 | qaanaaq
# Processing Record 28 of Set 5 | corinto
# Processing Record 29 of Set 5 | severnyy-kospashskiy
# Processing Record 30 of Set 5 | bairiki
# Processing Record 31 of Set 5 | kruisfontein
# Processing Record 32 of Set 5 | batagay-alyta
# Processing Record 33 of Set 5 | srednekolymsk
# Processing Record 34 of Set 5 | gamba
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | yaan
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | pangai
# Processing Record 40 of Set 5 | morant bay
# Processing Record 41 of Set 5 | lindi
# Processing Record 42 of Set 5 | usinsk
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | kalmunai
# Processing Record 45 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | vernon
# Processing Record 48 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 49 of Set 5 | yakeshi
# Processing Record 50 of Set 5 | rocha
# Processing Record 1 of Set 6 | fonte boa
# Processing Record 2 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | hebi
# Processing Record 7 of Set 6 | bichura
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | svetlyy
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | ketegyhaza
# Processing Record 12 of Set 6 | itarema
# Processing Record 13 of Set 6 | dabola
# Processing Record 14 of Set 6 | zhigansk
# Processing Record 15 of Set 6 | sisimiut
# Processing Record 16 of Set 6 | moindou
# Processing Record 17 of Set 6 | jaboatao
# Processing Record 18 of Set 6 | jieshi
# Processing Record 19 of Set 6 | maniitsoq
# Processing Record 20 of Set 6 | esplanada
# Processing Record 21 of Set 6 | basco
# Processing Record 22 of Set 6 | bay roberts
# Processing Record 23 of Set 6 | angoche
# Processing Record 24 of Set 6 | warrington
# Processing Record 25 of Set 6 | lao cai
# Processing Record 26 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 6 | honningsvag
# Processing Record 28 of Set 6 | kulhudhuffushi
# Processing Record 29 of Set 6 | ambilobe
# Processing Record 30 of Set 6 | cherskiy
# Processing Record 31 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 6 | shimanovsk
# Processing Record 33 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 6 | oranjestad
# Processing Record 35 of Set 6 | leshukonskoye
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 6 | aswan
# Processing Record 39 of Set 6 | port-gentil
# Processing Record 40 of Set 6 | flinders
# Processing Record 41 of Set 6 | cerrik
# Processing Record 42 of Set 6 | starosubkhangulovo
# Processing Record 43 of Set 6 | daoukro
# Processing Record 44 of Set 6 | weligama
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | anloga
# Processing Record 47 of Set 6 | narsaq
# Processing Record 48 of Set 6 | corrente
# Processing Record 49 of Set 6 | machali
# Processing Record 50 of Set 6 | rognan
# Processing Record 1 of Set 7 | sinnamary
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | castro
# Processing Record 4 of Set 7 | wanning
# Processing Record 5 of Set 7 | conde
# Processing Record 6 of Set 7 | klaksvik
# Processing Record 7 of Set 7 | aljezur
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | san rafael
# Processing Record 10 of Set 7 | gat
# Processing Record 11 of Set 7 | mogadishu
# Processing Record 12 of Set 7 | petrivka
# Processing Record 13 of Set 7 | gogrial
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | cabano
# Processing Record 16 of Set 7 | sayyan
# Processing Record 17 of Set 7 | najran
# Processing Record 18 of Set 7 | sandwick
# Processing Record 19 of Set 7 | cercal
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | lunenburg
# Processing Record 22 of Set 7 | sawtell
# Processing Record 23 of Set 7 | bolitoc
# Processing Record 24 of Set 7 | kontagora
# Processing Record 25 of Set 7 | aragarcas
# Processing Record 26 of Set 7 | preobrazheniye
# Processing Record 27 of Set 7 | upata
# Processing Record 28 of Set 7 | krasnoselkup
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | singkang
# Processing Record 31 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 7 | ponta do sol
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | kahului
# Processing Record 35 of Set 7 | fayaoue
# Processing Record 36 of Set 7 | aygedzor
# Processing Record 37 of Set 7 | byron bay
# Processing Record 38 of Set 7 | sur
# Processing Record 39 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 7 | fevik
# Processing Record 41 of Set 7 | kavieng
# Processing Record 42 of Set 7 | roald
# Processing Record 43 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 7 | tynda
# Processing Record 45 of Set 7 | izoplit
# Processing Record 46 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 7 | yei
# Processing Record 48 of Set 7 | honiara
# Processing Record 49 of Set 7 | ouadda
# Processing Record 50 of Set 7 | silver city
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | malinyi
# Processing Record 3 of Set 8 | alenquer
# Processing Record 4 of Set 8 | prince rupert
# Processing Record 5 of Set 8 | kurtamysh
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | makat
# Processing Record 8 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 8 | hornepayne
# Processing Record 10 of Set 8 | yangjiang
# Processing Record 11 of Set 8 | san patricio
# Processing Record 12 of Set 8 | maceio
# Processing Record 13 of Set 8 | yellowknife
# Processing Record 14 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | christchurch
# Processing Record 17 of Set 8 | waipawa
# Processing Record 18 of Set 8 | ipixuna
# Processing Record 19 of Set 8 | caravelas
# Processing Record 20 of Set 8 | zheleznodorozhnyy
# Processing Record 21 of Set 8 | belmonte
# Processing Record 22 of Set 8 | eureka
# Processing Record 23 of Set 8 | kenai
# Processing Record 24 of Set 8 | puqi
# Processing Record 25 of Set 8 | sola
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | point fortin
# Processing Record 28 of Set 8 | bonavista
# Processing Record 29 of Set 8 | banda aceh
# Processing Record 30 of Set 8 | flin flon
# Processing Record 31 of Set 8 | aniva
# Processing Record 32 of Set 8 | datong
# Processing Record 33 of Set 8 | hammond
# Processing Record 34 of Set 8 | nizhniy kuranakh
# Processing Record 35 of Set 8 | brae
# Processing Record 36 of Set 8 | khash
# Processing Record 37 of Set 8 | sabang
# Processing Record 38 of Set 8 | soyo
# Processing Record 39 of Set 8 | south lake tahoe
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | puerto carreno
# Processing Record 42 of Set 8 | general roca
# Processing Record 43 of Set 8 | skibbereen
# Processing Record 44 of Set 8 | sakakah
# Processing Record 45 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 8 | bambanglipuro
# Processing Record 47 of Set 8 | manali
# Processing Record 48 of Set 8 | ocos
# Processing Record 49 of Set 8 | moerai
# Processing Record 50 of Set 8 | omboue
# Processing Record 1 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 9 | varhaug
# Processing Record 3 of Set 9 | sokoni
# Processing Record 4 of Set 9 | lavrentiya
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | ngunguru
# Processing Record 7 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 9 | ostrovnoy
# Processing Record 9 of Set 9 | rio grande
# Processing Record 10 of Set 9 | jega
# Processing Record 11 of Set 9 | tarakan
# Processing Record 12 of Set 9 | takab
# Processing Record 13 of Set 9 | saint-ambroise
# Processing Record 14 of Set 9 | lazaro cardenas
# Processing Record 15 of Set 9 | pachino
# Processing Record 16 of Set 9 | victoria
# Processing Record 17 of Set 9 | shimoda
# Processing Record 18 of Set 9 | salvador
# Processing Record 19 of Set 9 | nioro
# Processing Record 20 of Set 9 | martapura
# Processing Record 21 of Set 9 | mahebourg
# Processing Record 22 of Set 9 | anuradhapura
# Processing Record 23 of Set 9 | slave lake
# Processing Record 24 of Set 9 | boffa
# Processing Record 25 of Set 9 | ketchikan
# Processing Record 26 of Set 9 | dukhovshchina
# Processing Record 27 of Set 9 | nabire
# Processing Record 28 of Set 9 | san cristobal
# Processing Record 29 of Set 9 | pochutla
# Processing Record 30 of Set 9 | snezhnogorsk
# Processing Record 31 of Set 9 | nicoya
# Processing Record 32 of Set 9 | salalah
# Processing Record 33 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 9 | palestine
# Processing Record 35 of Set 9 | gboko
# Processing Record 36 of Set 9 | kropotkin
# Processing Record 37 of Set 9 | krieglach
# Processing Record 38 of Set 9 | abnub
# Processing Record 39 of Set 9 | nguruka
# Processing Record 40 of Set 9 | jawhar
# Processing Record 41 of Set 9 | outjo
# Processing Record 42 of Set 9 | sijunjung
# Processing Record 43 of Set 9 | gotsu
# Processing Record 44 of Set 9 | nanakuli
# Processing Record 45 of Set 9 | cap malheureux
# Processing Record 46 of Set 9 | bridlington
# Processing Record 47 of Set 9 | ube
# Processing Record 48 of Set 9 | tiarei
# Processing Record 49 of Set 9 | wajir
# Processing Record 50 of Set 9 | barra patuca
# Processing Record 1 of Set 10 | karsava
# Processing Record 2 of Set 10 | kawalu
# Processing Record 3 of Set 10 | kamwenge
# Processing Record 4 of Set 10 | atar
# Processing Record 5 of Set 10 | ojinaga
# Processing Record 6 of Set 10 | shintomi
# Processing Record 7 of Set 10 | lata
# Processing Record 8 of Set 10 | vardo
# Processing Record 9 of Set 10 | kangaatsiaq
# Processing Record 10 of Set 10 | kloulklubed
# Processing Record 11 of Set 10 | gijon
# Processing Record 12 of Set 10 | jining
# Processing Record 13 of Set 10 | horve
# Processing Record 14 of Set 10 | toba
# Processing Record 15 of Set 10 | nizwa
# Processing Record 16 of Set 10 | haapiti
# Processing Record 17 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 10 | hukuntsi
# Processing Record 19 of Set 10 | xam nua
# Processing Record 20 of Set 10 | flekkefjord
# Processing Record 21 of Set 10 | beloomut
# Processing Record 22 of Set 10 | maragogi
# Processing Record 23 of Set 10 | alyangula
# Processing Record 24 of Set 10 | egvekinot
# Processing Record 25 of Set 10 | estevan
# Processing Record 26 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 10 | krivodol
# Processing Record 28 of Set 10 | jacareacanga
# Processing Record 29 of Set 10 | segovia
# Processing Record 30 of Set 10 | saldanha
# Processing Record 31 of Set 10 | umm kaddadah
# Processing Record 32 of Set 10 | bathsheba
# Processing Record 33 of Set 10 | comodoro rivadavia
# Processing Record 34 of Set 10 | kailua
# Processing Record 35 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 10 | mongoumba
# Processing Record 37 of Set 10 | troy
# Processing Record 38 of Set 10 | talara
# Processing Record 39 of Set 10 | linxia
# Processing Record 40 of Set 10 | bagn
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | nalobikha
# Processing Record 43 of Set 10 | iquique
# Processing Record 44 of Set 10 | inta
# Processing Record 45 of Set 10 | naron
# Processing Record 46 of Set 10 | okha
# Processing Record 47 of Set 10 | kholtoson
# Processing Record 48 of Set 10 | chau doc
# Processing Record 49 of Set 10 | yatou
# Processing Record 50 of Set 10 | jiexiu
# Processing Record 1 of Set 11 | daru
# Processing Record 2 of Set 11 | halifax
# Processing Record 3 of Set 11 | hondo
# Processing Record 4 of Set 11 | waingapu
# Processing Record 5 of Set 11 | sao felix do xingu
# Processing Record 6 of Set 11 | tutoia
# Processing Record 7 of Set 11 | bartica
# Processing Record 8 of Set 11 | severomuysk
# Processing Record 9 of Set 11 | parabel
# Processing Record 10 of Set 11 | hualmay
# Processing Record 11 of Set 11 | san lorenzo de el escorial
# Processing Record 12 of Set 11 | chikwawa
# Processing Record 13 of Set 11 | cuiluan
# Processing Record 14 of Set 11 | havelock
# Processing Record 15 of Set 11 | mareeba
# Processing Record 16 of Set 11 | saint-pierre
# Processing Record 17 of Set 11 | haines junction
# Processing Record 18 of Set 11 | sillamae
# Processing Record 19 of Set 11 | atasu
# Processing Record 20 of Set 11 | tacuarembo
# Processing Record 21 of Set 11 | boali
# Processing Record 22 of Set 11 | mount isa
# Processing Record 23 of Set 11 | mirnyy
# Processing Record 24 of Set 11 | rafraf
# Processing Record 25 of Set 11 | anapskaya
# Processing Record 26 of Set 11 | amposta
# Processing Record 27 of Set 11 | kampene
# Processing Record 28 of Set 11 | puerto narino
# Processing Record 29 of Set 11 | abu kamal
# Processing Record 30 of Set 11 | port keats
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | ossora
# Processing Record 33 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 11 | viransehir
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | kempsey
# Processing Record 37 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 11 | regina
# Processing Record 39 of Set 11 | berlin
# Processing Record 40 of Set 11 | huancavelica
# Processing Record 41 of Set 11 | mountain home
# Processing Record 42 of Set 11 | kikwit
# Processing Record 43 of Set 11 | baleshwar
# Processing Record 44 of Set 11 | huarmey
# Processing Record 45 of Set 11 | petropavlivka
# Processing Record 46 of Set 11 | arman
# Processing Record 47 of Set 11 | takoradi
# Processing Record 48 of Set 11 | lander
# Processing Record 49 of Set 11 | vila franca do campo
# Processing Record 50 of Set 11 | ghanzi
# Processing Record 1 of Set 12 | sikasso
# Processing Record 2 of Set 12 | monrovia
# Processing Record 3 of Set 12 | challans
# Processing Record 4 of Set 12 | pirai do sul
# Processing Record 5 of Set 12 | witu
# Processing Record 6 of Set 12 | kosya
# City not found. Skipping...
# Processing Record 7 of Set 12 | belaya gora
# Processing Record 8 of Set 12 | sembe
# Processing Record 9 of Set 12 | dublin
# Processing Record 10 of Set 12 | burnie
# Processing Record 11 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 12 | akyab
# Processing Record 13 of Set 12 | wamba
# Processing Record 14 of Set 12 | karachi
# Processing Record 15 of Set 12 | palmas bellas
# Processing Record 16 of Set 12 | gornozavodsk
# Processing Record 17 of Set 12 | matviyivka
# Processing Record 18 of Set 12 | kirakira
# Processing Record 19 of Set 12 | iberia
# Processing Record 20 of Set 12 | lakatoro
# Processing Record 21 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 12 | mutare
# Processing Record 23 of Set 12 | ust-ishim
# Processing Record 24 of Set 12 | kasongo-lunda
# Processing Record 25 of Set 12 | tigzirt
# Processing Record 26 of Set 12 | aktau
# Processing Record 27 of Set 12 | port hedland
# Processing Record 28 of Set 12 | dongkan
# Processing Record 29 of Set 12 | padang
# Processing Record 30 of Set 12 | manturovo
# Processing Record 31 of Set 12 | nelson bay
# Processing Record 32 of Set 12 | balotra
# Processing Record 33 of Set 12 | saint anthony
# Processing Record 34 of Set 12 | akropong
# Processing Record 35 of Set 12 | shache
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | yulara
# Processing Record 38 of Set 12 | coihaique
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | bontang
# Processing Record 41 of Set 12 | navolato
# Processing Record 42 of Set 12 | taoudenni
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | birzai
# Processing Record 45 of Set 12 | sao jose da coroa grande
# Processing Record 46 of Set 12 | kivsharivka
# Processing Record 47 of Set 12 | nacala
# Processing Record 48 of Set 12 | san jeronimo
# Processing Record 49 of Set 12 | ye
# City not found. Skipping...
# Processing Record 50 of Set 12 | myitkyina
# Processing Record 1 of Set 13 | ibotirama
# Processing Record 2 of Set 13 | svetlogorsk
# Processing Record 3 of Set 13 | vangaindrano
# Processing Record 4 of Set 13 | gondanglegi
# Processing Record 5 of Set 13 | bushehr
# Processing Record 6 of Set 13 | dejen
# Processing Record 7 of Set 13 | talakan
# Processing Record 8 of Set 13 | lahaina
# Processing Record 9 of Set 13 | takapau
# Processing Record 10 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 13 | pingdingshan
# Processing Record 12 of Set 13 | knysna
# Processing Record 13 of Set 13 | katsuura
# Processing Record 14 of Set 13 | sibolga
# Processing Record 15 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 13 | panjab
# Processing Record 17 of Set 13 | quatre cocos
# Processing Record 18 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 13 | chara
# Processing Record 20 of Set 13 | kieta
# Processing Record 21 of Set 13 | san andres
# Processing Record 22 of Set 13 | dawei
# Processing Record 23 of Set 13 | oytal
# Processing Record 24 of Set 13 | guerrero negro
# Processing Record 25 of Set 13 | male
# Processing Record 26 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 13 | komsomolskiy
# Processing Record 28 of Set 13 | mabaruma
# Processing Record 29 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 13 | puerto del rosario
# Processing Record 31 of Set 13 | cuamba
# Processing Record 32 of Set 13 | porto seguro
# Processing Record 33 of Set 13 | thinadhoo
# Processing Record 34 of Set 13 | nampula
# Processing Record 35 of Set 13 | meulaboh
# Processing Record 36 of Set 13 | nebolchi
# Processing Record 37 of Set 13 | santa marta
# Processing Record 38 of Set 13 | eseka
# Processing Record 39 of Set 13 | hervey bay
# Processing Record 40 of Set 13 | tshikapa
# Processing Record 41 of Set 13 | touros
# Processing Record 42 of Set 13 | bagan
# Processing Record 43 of Set 13 | gari
# Processing Record 44 of Set 13 | gizo
# Processing Record 45 of Set 13 | ranibennur
# Processing Record 46 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 47 of Set 13 | menongue
# Processing Record 48 of Set 13 | phonhong
# Processing Record 49 of Set 13 | soldatskiy
# City not found. Skipping...
# Processing Record 50 of Set 13 | faya
# Processing Record 1 of Set 14 | mugla
# Processing Record 2 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 14 | mecca
# Processing Record 4 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 5 of Set 14 | sale
# Processing Record 6 of Set 14 | gornopravdinsk
# Processing Record 7 of Set 14 | san policarpo
# Processing Record 8 of Set 14 | miramar
# Processing Record 9 of Set 14 | livingston
# Processing Record 10 of Set 14 | kassala
# Processing Record 11 of Set 14 | umm lajj
# Processing Record 12 of Set 14 | fortuna
# Processing Record 13 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 14 | nisia floresta
# Processing Record 15 of Set 14 | yar-sale
# Processing Record 16 of Set 14 | ivdel
# Processing Record 17 of Set 14 | kirovskiy
# Processing Record 18 of Set 14 | glace bay
# Processing Record 19 of Set 14 | stokmarknes
# Processing Record 20 of Set 14 | general higinio morinigo
# Processing Record 21 of Set 14 | dong hoi
# Processing Record 22 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 14 | chenzhou
# Processing Record 24 of Set 14 | blagoyevo
# Processing Record 25 of Set 14 | kalevala
# Processing Record 26 of Set 14 | tabou
# Processing Record 27 of Set 14 | bodden town
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | wylie
# Processing Record 30 of Set 14 | leonidovo
# Processing Record 31 of Set 14 | koumac
# Processing Record 32 of Set 14 | tanggu
# Processing Record 33 of Set 14 | pokhara
# Processing Record 34 of Set 14 | jamtara
# Processing Record 35 of Set 14 | carolina
# Processing Record 36 of Set 14 | bubaque
# Processing Record 37 of Set 14 | poya
# Processing Record 38 of Set 14 | aktanysh
# Processing Record 39 of Set 14 | kollam
# Processing Record 40 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 41 of Set 14 | mtwara
# Processing Record 42 of Set 14 | mwinilunga
# Processing Record 43 of Set 14 | morgan city
# Processing Record 44 of Set 14 | samoylovka
# Processing Record 45 of Set 14 | russell
# Processing Record 46 of Set 14 | kitob
# Processing Record 47 of Set 14 | sao miguel do araguaia
# Processing Record 48 of Set 14 | marsh harbour
# Processing Record 49 of Set 14 | aasiaat
# Processing Record 50 of Set 14 | moose factory
# Processing Record 1 of Set 15 | guadalupe y calvo
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | north bend
# Processing Record 4 of Set 15 | madang
# Processing Record 5 of Set 15 | kedrovyy
# Processing Record 6 of Set 15 | krizevci
# Processing Record 7 of Set 15 | kholm-zhirkovskiy
# Processing Record 8 of Set 15 | hobyo
# Processing Record 9 of Set 15 | payakumbuh
# Processing Record 10 of Set 15 | ubinskoye
# Processing Record 11 of Set 15 | kazerun
# Processing Record 12 of Set 15 | kuito
# Processing Record 13 of Set 15 | sembakung
# Processing Record 14 of Set 15 | cedar city
# Processing Record 15 of Set 15 | karonga
# Processing Record 16 of Set 15 | lahat
# Processing Record 17 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 15 | half moon bay
# Processing Record 19 of Set 15 | umba
# Processing Record 20 of Set 15 | may pen
# Processing Record 21 of Set 15 | asau
# Processing Record 22 of Set 15 | wageningen
# Processing Record 23 of Set 15 | praia da vitoria
# Processing Record 24 of Set 15 | port shepstone
# Processing Record 25 of Set 15 | brunico
# Processing Record 26 of Set 15 | aksarka
# Processing Record 27 of Set 15 | ust-maya
# Processing Record 28 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 15 | tevaitoa
# Processing Record 30 of Set 15 | dekar
# Processing Record 31 of Set 15 | bratsk
# Processing Record 32 of Set 15 | bilibino
# Processing Record 33 of Set 15 | sept-iles
# Processing Record 34 of Set 15 | hvide sande
# Processing Record 35 of Set 15 | teya
# Processing Record 36 of Set 15 | la rioja
# Processing Record 37 of Set 15 | dawson creek
# Processing Record 38 of Set 15 | pandan
# Processing Record 39 of Set 15 | bonthe
# Processing Record 40 of Set 15 | sangar
# Processing Record 41 of Set 15 | lyubytino
# Processing Record 42 of Set 15 | muzambinho
# Processing Record 43 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 15 | saint-paul
# Processing Record 45 of Set 15 | kutulik
# Processing Record 46 of Set 15 | gusau
# Processing Record 47 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 15 | nuevo progreso
# Processing Record 49 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 50 of Set 15 | kang
# Processing Record 1 of Set 16 | inverell
# Processing Record 2 of Set 16 | ibra
# Processing Record 3 of Set 16 | khvorostyanka
# Processing Record 4 of Set 16 | natitingou
# Processing Record 5 of Set 16 | portland
# Processing Record 6 of Set 16 | taltal
# Processing Record 7 of Set 16 | nouakchott
# Processing Record 8 of Set 16 | belem
# Processing Record 9 of Set 16 | tlahualilo
# City not found. Skipping...
# Processing Record 10 of Set 16 | lincoln
# Processing Record 11 of Set 16 | bougouni
# Processing Record 12 of Set 16 | kantemirovka
# Processing Record 13 of Set 16 | wangou
# Processing Record 14 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 16 | hokitika
# Processing Record 16 of Set 16 | kamarion
# Processing Record 17 of Set 16 | biltine
# Processing Record 18 of Set 16 | jiuquan
# Processing Record 19 of Set 16 | sachin
# Processing Record 20 of Set 16 | cairns
# Processing Record 21 of Set 16 | lokken verk
# City not found. Skipping...
# Processing Record 22 of Set 16 | strezhevoy
# Processing Record 23 of Set 16 | benguela
# Processing Record 24 of Set 16 | cicero dantas
# Processing Record 25 of Set 16 | gejiu
# Processing Record 26 of Set 16 | oyem
# Processing Record 27 of Set 16 | thunder bay
# Processing Record 28 of Set 16 | gidam
# Processing Record 29 of Set 16 | krasnaya gora
# Processing Record 30 of Set 16 | tomatlan
# Processing Record 31 of Set 16 | ixtapa
# Processing Record 32 of Set 16 | yerbogachen
# Processing Record 33 of Set 16 | raudeberg
# Processing Record 34 of Set 16 | okitipupa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Te Anau -45.4167  167.7167     43.25        83          57
# 1       Ushuaia -54.8000  -68.3000     53.26        40          40
# 2  Port Lincoln -34.7333  135.8667     58.98        77           0
# 3      Tongliao  43.6125  122.2653     24.39        78          34
# 4       Oropesa -13.5928  -71.7719     62.46        44          75
# 5        Avarua -21.2078 -159.7750     75.25        73          16
# 6         Moron -34.6534  -58.6198     66.09        94          90
# 7     Busselton -33.6500  115.3333     59.29        91          77
# 8         Ginda  30.6945   78.4932     45.19        26           0
# 9       Rikitea -23.1203 -134.9692     76.44        73           7
#
#    Wind Speed Country     Current Description
# 0        0.40      NZ           broken clouds
# 1       23.02      AR              light rain
# 2        7.25      AU               clear sky
# 3       11.70      CN        scattered clouds
# 4        2.30      PE           broken clouds
# 5        1.14      CK              few clouds
# 6        5.75      AR  thunderstorm with rain
# 7        8.14      AU           broken clouds
# 8        6.69      IN               clear sky
# 9       16.58      PF               clear sky

# %%
# Reorder the columns

new_column_order = [ "City" , "Country" , "Lat" , "Lng" , "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

city_data_df = city_data_df [new_column_order]

city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Te Anau      NZ -45.4167  167.7167     43.25        83          57
# 1       Ushuaia      AR -54.8000  -68.3000     53.26        40          40
# 2  Port Lincoln      AU -34.7333  135.8667     58.98        77           0
# 3      Tongliao      CN  43.6125  122.2653     24.39        78          34
# 4       Oropesa      PE -13.5928  -71.7719     62.46        44          75
# 5        Avarua      CK -21.2078 -159.7750     75.25        73          16
# 6         Moron      AR -34.6534  -58.6198     66.09        94          90
# 7     Busselton      AU -33.6500  115.3333     59.29        91          77
# 8         Ginda      IN  30.6945   78.4932     45.19        26           0
# 9       Rikitea      PF -23.1203 -134.9692     76.44        73           7
#
#    Wind Speed     Current Description
# 0        0.40           broken clouds
# 1       23.02              light rain
# 2        7.25               clear sky
# 3       11.70        scattered clouds
# 4        2.30           broken clouds
# 5        1.14              few clouds
# 6        5.75  thunderstorm with rain
# 7        8.14           broken clouds
# 8        6.69               clear sky
# 9       16.58               clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
